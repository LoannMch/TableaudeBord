# %%
import requests
import bs4



req = requests.get('http://map.norsecorp.com/#')
data = req.text
soup = bs4.BeautifulSoup(data, "lxml")

# %%
data
# Out:
# '<!doctype html>\n<html lang=\'en\' ng-app=\'norse-map\'>\n  <head>\n    <meta charset=\'utf-8\'>\n    <title>Norse Attack Map</title>\n    <link rel=\'stylesheet\' type=\'text/css\' href=\'http://fonts.googleapis.com/css?family=Oswald:bold,700,400,300|Open+Sans\'>\n    <link rel=\'stylesheet\' href=\'css/styles.css\'>\n  </head>\n  <body>\n    <div id="particleHiddenDiv" style="display:none"></div>\n    <div id="chevronHiddenDiv" style="display:none"></div>\n    <div id=\'map\'>\n      <div class="loading-screen">\n        <div class="loading-content">\n          <noscript>\n            <p>This site requires javascript to function.</p>\n            <p>Please enable javascript and reload.</p>\n          </noscript>\n          <img class="loading-img" src="/img/norse-mark-60px-white.svg">\n          <p>LOADING</p>\n        </div>\n      </div>\n    </div>\n    <div id=\'controls\' ng-controller="LogoCtrl">\n      <div>\n        <i class="fa fa-image fa-2x" id="addLogoIcon" ng-click="a
# ...

# %%
#<tr class = 'row ng-scope'
balises_tr = soup.find_all()

# %%
balises_tr
# Out:
# [<html lang="en" ng-app="norse-map">
#  <head>
#  <meta charset="utf-8"/>
#  <title>Norse Attack Map</title>
#  <link href="http://fonts.googleapis.com/css?family=Oswald:bold,700,400,300|Open+Sans" rel="stylesheet" type="text/css"/>
#  <link href="css/styles.css" rel="stylesheet"/>
#  </head>
#  <body>
#  <div id="particleHiddenDiv" style="display:none"></div>
#  <div id="chevronHiddenDiv" style="display:none"></div>
#  <div id="map">
#  <div class="loading-screen">
#  <div class="loading-content">
#  <noscript>
#  <p>This site requires javascript to function.</p>
#  <p>Please enable javascript and reload.</p>
#  </noscript>
#  <img class="loading-img" src="/img/norse-mark-60px-white.svg"/>
#  <p>LOADING</p>
#  </div>
#  </div>
#  </div>
#  <div id="controls" ng-controller="LogoCtrl">
#  <div>
#  <i class="fa fa-image fa-2x" id="addLogoIcon" ng-click="addLogo()"></i>
#  <img id="logo1" ng-src="{{logo1}}"/>
#  </div>
#  <div id="divlogo2" ng-cloak="" ng-if="powered_by">
# ...
